# %%
from gapminder import gapminder
import pandas as pd
import seaborn as sns

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
data = gapminder[gapminder['country'] == 'Afghanistan']

# %%
data.plot(title="Life Expectancy in Afghanistan",
         y = 'pop',
         x = 'year')
# Out:
# <AxesSubplot:title={'center':'Life Expectancy in Afghanistan'}, xlabel='year'>

# %% [markdown]
# ### Area Map

# %%
data.plot(title="Life Expectancy in Afghanistan",
         y = 'pop',
         x = 'year',
         kind = 'area')
# Out:
# <AxesSubplot:title={'center':'Life Expectancy in Afghanistan'}, xlabel='year'>

# %% [markdown]
# ### Scatter Plot

# %%
data.plot(title="Life Expectancy in Afghanistan",
         y = 'pop',
         x = 'year',
         kind = 'scatter')
# Out:
# <AxesSubplot:title={'center':'Life Expectancy in Afghanistan'}, xlabel='year', ylabel='pop'>

# %% [markdown]
# ## Using Histogram to Compare Across Countries

# %%
data_2007 = gapminder[gapminder['year'] == 2007]

# %%
data_2007.plot(title='Populations in 2007',
              kind = 'hist',
              y='pop',
              bins=100)
# Out:
# <AxesSubplot:title={'center':'Populations in 2007'}, ylabel='Frequency'>

# %% [markdown]
# ### Using Scatterplot to View Trends Between Variables

# %%
gapminder.plot(title = 'GDP per Capita vs. Life Expectancy',
         kind = 'scatter',
         x = 'gdpPercap',
         y = 'lifeExp')
# Out:
# <AxesSubplot:title={'center':'GDP per Capita vs. Life Expectancy'}, xlabel='gdpPercap', ylabel='lifeExp'>

# %% [markdown]
# ### Logging Variables for Exploratory Data Analysis

# %%
gapminder.plot(title = 'GDP per Capita vs. Life Expectancy',
         kind = 'scatter',
         x = 'gdpPercap',
         y = 'lifeExp',
         logx = True)
# Out:
# <AxesSubplot:title={'center':'GDP per Capita vs. Life Expectancy'}, xlabel='gdpPercap', ylabel='lifeExp'>

# %% [markdown]
# ### Using Color to Distinguish Variables

# %%
gapminder.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
## create dictionary of color keys

cont_color = {'Asia':'red',
             'Africa':'orange',
             'Americas':'navy',
             'Europe':'green',
             'Oceania':'teal'}

## create new column in gapminder dataset
gapminder['color'] = [cont_color[country] for country in gapminder['continent']]

# %%
gapminder.plot(title = 'GDP per Capita vs. Life Expectancy',
         kind = 'scatter',
         x = 'gdpPercap',
         y = 'lifeExp',
         logx = True,
         c = gapminder['color'])
# Out:
# <AxesSubplot:title={'center':'GDP per Capita vs. Life Expectancy'}, xlabel='gdpPercap', ylabel='lifeExp'>

# %%
g = sns.PairGrid(gapminder, diag_sharey = False)

g.map_lower(sns.kdeplot)

g.map_upper(sns.scatterplot)

g.map_diag(sns.kdeplot, lw=3)

# %% [markdown]
# ### Using `pandas_profiling` to Assess Data

# %%
from pandas_profiling import ProfileReport

gapminder.profile_report()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-09-15 17:16:20.674784&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
